# %% [markdown]
# # March Madness Lab
#
# Get the March Madness data for 2026 from Kaggle: https://www.kaggle.com/competitions/march-machine-learning-mania-2026
#
# We want to train a machine to predict who will win the tournament (i.e. fill out a bracket).
#
# Let's develop some promising solutions:
#
# 1. What is an observation? What do you want to predict?\
# **An observation (row) is one game. We want to predict the difference between winning and losing teams to see which team is more likely to win.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

wdf = pd.read_csv("data/WRegularSeasonCompactResults.csv")
df = pd.read_csv("data/game_team_performance.csv")
print(wdf.shape)
pd.set_option('display.max_columns', None)
df.head()
# Out:
# (142507, 8)
#                             game_id       game_type  Season  DayNum  TeamID  \
# 0  regular_season_1998_18_3104_3202  regular_season    1998      18    3104
# 1  regular_season_1998_18_3104_3202  regular_season    1998      18    3202
# 2  regular_season_1998_18_3163_3221  regular_season    1998      18    3163
# 3  regular_season_1998_18_3163_3221  regular_season    1998      18    3221
# 4  regular_season_1998_18_3222_3261  regular_season    1998      18    3222
#
#       TeamName  OpponentTeamID OpponentTeamName  Points  OpponentPoints  \
# 0      Alabama            3202           Furman      91              41
# 1       Furman            3104          Alabama      41              91
# 2  Connecticut            3221       Holy Cross      87              76
# 3   Holy Cross            3163      Connecticut      76              87
# 4      Houston            3261              LSU      66              59
#
#    margin TeamResult TeamLoc  is_neutral_site  NumOT  team_year  \
# 0      50          W       H            False      0  1998_3104
# 1     -50          L       A            False      0  1998_3202
# 2      11          W       H            False      0  1998_3163
# 3     -11          L       A            False      0  1998_3221
# 4       7          W       H            False      0  1998_3222
#
#   opponent_team_year offense_team_year defense_opponent_team_year  \
# 0          1998_3202         1998_3104                  1998_3202
# 1          1998_3104         1998_3202                  1998_3104
# 2          1998_3221         1998_3163                  1998_3221
# 3          1998_3163         1998_3221                  1998_3163
# 4          1998_3261         1998_3222                  1998_3261
#
#   TeamConfAbbrev OpponentConfAbbrev  is_conference_game  \
# 0            sec           southern               False
# 1       southern                sec               False
# 2       big_east            patriot               False
# 3        patriot           big_east               False
# 4           cusa                sec               False
#
#    is_out_of_conference_game PossessionRow
# 0                       True       offense
# 1                       True       offense
# 2                       True       offense
# 3                       True       offense
# 4                       True       offense

# %% [markdown]
# 2. "Identification" is the mathematical-statistical concept that deals with whether the model can actually be fitted from the data or not. The identification challenge with the NCAA tournaments is that most teams in the tournament never play each other in the regular season. What kind of linear, logistic, or generalized linear model can provide predictions about out-of-conference play? How are you extrapolating? What are practical concerns that might arise from your strategy?\
# **We want to use OLS. We want to split a single game into a vs. b and b vs. a.**

# %% [markdown]
# 4. Normally we do a train/test split or k-fold cross validation. Surely we'll use those specific tools somewhere (e.g. regularization), but for model validation, how can you use the structure of the data to test your approach to using regular season data to evaluate whether your model will perform well in the tournament?

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PoissonRegressor, LogisticRegression, Ridge, LinearRegression
from sklearn.model_selection import KFold, cross_val_score

mse = lambda y, y_a : np.mean((y-y_hat)**2)

df["offense_team_year"] = df["Team"]

# %% [markdown]
# 5. How should you build your data analytics pipeline to minimize the costs of making predictions?

# %% [markdown]
# 6. What are the predictive advantages and disadvantages of a logistic regression that predicts which team wins, over a linear model that predicts points scores? How can you build your code base to be modular, and avoid over-committing to one model type or another?

# %% [markdown]
# 7. How do you approach this project to (1) maintain control and create what you want to build but (2) use AI to accelerate the development and get work done quickly?
